# %% [markdown]
# <a href="https://colab.research.google.com/github/hendokapi/first-colab/blob/main/PythonRevision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Elementi base di Python
# Link al sito di [Python](https://www.python.org/)

# %% [markdown]
# ## Elementi trattati
# - Variabili
# - Stringhe
# - Condizionale
# - Cicli
# - Dizionari e tuple
# - Funzioni
# - Gestione dei file
# - Gestione delle eccezioni

# %% [markdown]
# # Github
